# %%
import os
from visualisation.plot_kelly_bet import plot_kelly_bet
from visualisation.plot_metrics_v_diff_v_prev import plot_metrics_v_diff_v_prev
from visualisation.plot_imv_v_altmet import plot_imv_v_altmet
from visualisation.plot_se_vs_sd import plot_se_vs_sd
from visualisation.plot_linear_v_quadratic import plot_linear_v_quadratic  
from visualisation.plot_hrs_descriptives import plot_hrs_descriptives
from visualisation.plot_hrs_imv import plot_hrs_imv
from visualisation.plot_covid_imv import plot_covid_imv
from visualisation.plot_football_imv import plot_football_imv
from empirical.make_titanic_competition import titanic_main
figure_path = os.path.join(os.getcwd(), '..', 'results', 'figures')
sim_path = os.path.join(os.getcwd(), '..', 'data', 'sims')
data_path = os.path.join(os.getcwd(), '..', 'data')
table_path = os.path.join(os.getcwd(), '..', 'results', 'tables')
# %reload_ext autoreload
# %autoreload 2

style_dict = {'font': 'DejaVu Sans',
              'colours': ['#41558c', '#E89818', '#CF202A'],
              'line_width': 2,
              'letter_size': 16,
              'label_size': 22,
             }

# %% [markdown]
# Figure S1

# %%
plot_kelly_bet(figure_path, style_dict, 'plot_kelly_bet.pdf')

# %% [markdown]
# Figure S2

# %%
plot_metrics_v_diff_v_prev(figure_path, data_path, style_dict, 'plot_metrics_v_diff_v_prev.pdf')

# %% [markdown]
# Figure S3

# %%
plot_imv_v_altmet(figure_path, data_path, style_dict, 'plot_imv_v_altmet.pdf')

# %% [markdown]
# Figure S4

# %%
plot_se_vs_sd(figure_path, data_path, style_dict, 'plot_se_vs_sd.pdf')

# %% [markdown]
# Figure S5

# %%
plot_linear_v_quadratic(figure_path, data_path, style_dict, 'plot_linear_v_quadratic.pdf')

# %% [markdown]
# Figure S6

# %%
plot_hrs_descriptives(figure_path, data_path, style_dict, 'plot_hrs_descriptives.pdf')

# %% [markdown]
# Figure S7

# %%
plot_hrs_imv(figure_path, data_path, style_dict, 'plot_hrs_imv.pdf')

# %% [markdown]
# Figure S8

# %%
plot_covid_imv(figure_path, data_path, style_dict, 'plot_covid_imv.pdf')

# %% [markdown]
# Figure S9

# %%
plot_football_imv(figure_path, data_path, style_dict, 'plot_football_imv.pdf')

# %% [markdown]
# Table S1

# %%
titanic_main(data_path, table_path)
