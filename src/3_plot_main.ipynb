# %%
import os
import matplotlib as mpl
from visualisation.plot_schematic import plot_schematic
from visualisation.plot_A_EPZP import plot_A_EPZP
from visualisation.plot_omega_oracle_overfit import plot_omega_oracle_overfit
from visualisation.plot_p0_v_p1 import plot_p0_v_p1
from visualisation.plot_prev_b0_v_b1 import plot_prev_b0_v_b1
from visualisation.plot_omega_rmse_aic_bic import plot_omega_rmse_aic_bic
from visualisation.plot_gss import plot_gss
from visualisation.plot_ffc import plot_ffc
figure_path = os.path.join(os.getcwd(), '..', 'results', 'figures')
sim_path = os.path.join(os.getcwd(), '..', 'data', 'sims')
data_path = os.path.join(os.getcwd(), '..', 'data')
table_path = os.path.join(os.getcwd(), '..', 'results', 'tables')
# %reload_ext autoreload
# %autoreload 2

style_dict = {'font': 'DejaVu Sans',
              'colours': ['#41558c', '#E89818', '#CF202A'],
              'line_width': 2,
              'letter_size': 16,
              'label_size': 22,
             }

# %% [markdown]
# Figure 1

# %%
plot_schematic(figure_path, style_dict, 'plot_schematic.pdf')

# %% [markdown]
# Figure 2

# %%
plot_A_EPZP(figure_path, style_dict, 'plot_A_EPZP.pdf')

# %% [markdown]
# Figure 3

# %%
plot_omega_oracle_overfit(figure_path, data_path, style_dict, 'plot_omega_oracle_overfit.pdf')

# %% [markdown]
# Figure 4

# %%
plot_p0_v_p1(figure_path, data_path, style_dict, 'plot_p0_v_p1.pdf')

# %% [markdown]
# Figure 5

# %%
plot_prev_b0_v_b1(figure_path, data_path, style_dict, 'plot_prev_b0_v_b1.pdf')

# %% [markdown]
# Figure 6

# %%
plot_omega_rmse_aic_bic(figure_path, data_path, style_dict, 'plot_omega_rmse_aic_bic.pdf')

# %% [markdown]
# Figure 7

# %%
plot_gss(figure_path, data_path, style_dict, 'plot_gss.pdf')

# %% [markdown]
# Figure 8

# %%
plot_ffc(figure_path, data_path, style_dict, 'plot_ffc.pdf')
# Out:
# Check len(bench) is (i.e. 1013 + 994 + 1104):  3201
# Check max IDs for any outcome (1104):  1104
# Check max IDs used across all team\outcome (1104):  1104
# Number of accounts in the subm file:  160
# We have 103 submissions for eviction
# We have 66 submissions for eviction which have an r2>0
# The min E(w) for eviction vs prev is -0.46868889651625445
# The min E(w) for eviction vs benchmark is -0.4700898764505974
# The max E(w) for eviction vs prev is 0.0074824111270946495
# The max E(w) for eviction vs benchmark is 0.004825845824887034
# The E(w) for eviction of benchmark vs prev is :0.002643806698688939
# The max R2 for eviction vs prev is :0.044145622700984766
# The R2 for eviction of benchmark is :0.01421584755055616
# The diff between R2 of bestr submission for eviction vs benchmark is :0.029929775150428606
# Spearmans Rho for incremental r2 and ew for eviction: 0.97192896688507
# We have 106 submissions for jobTraining
# ...
