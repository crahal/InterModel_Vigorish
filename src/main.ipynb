# %%
import os
import rpy2.robjects as robjects
from figure_1_function import make_figure_one
from figure_a1_function import make_figure_a1
from figure_2_function import make_figure_two
from figure_3_function import make_figure_three
from figure_4_function import make_figure_four
from figure_5_function import make_figure_five
from figure_6_function import make_figure_six
from figure_7_function import make_figure_seven
from make_logreg_figure import make_logreg_plotter
from titanic_competition import titanic_main
figure_path = os.path.join(os.getcwd(), '..', 'results', 'figures')
sim_path = os.path.join(os.getcwd(), '..', 'data', 'sims')
data_path = os.path.join(os.getcwd(), '..', 'data')
table_path = os.path.join(os.getcwd(), '..', 'results', 'tables')

# %%
make_figure_one(figure_path)

# %%
#sink = robjects.r("""source('make_logreg_sims.R')""")

# %%
make_logreg_plotter(figure_path, sim_path)

# %%
#sink = robjects.r("""source('make_r2_sims.R')""")

# %%
make_figure_two(figure_path, sim_path)

# %%
#sink = robjects.r("""source('src/make_simulations.R')""")

# %%
make_figure_three(figure_path, sim_path)

# %%
#sink = robjects.r("""source('src/make_hrs_prep.R')""")

# %%
make_figure_four(figure_path, sim_path)

# %%
#sink = robjects.r("""source('src/make_hrs_prep.R')""")

# %%
make_figure_a1(figure_path, data_path)

# %%
#sink = robjects.r("""source('src/make_hrs_pred.R')""")

# %%
make_figure_five(figure_path, data_path)

# %%
#sink = robjects.r("""source('src/make_gss_imv.R')""")

# %%
make_figure_six(figure_path, data_path )

# %%
make_figure_seven(figure_path, data_path)
# Out:
# Check len(bench) is (i.e. 1013 + 994 + 1104):  3201
# Check max IDs for any outcome (1104):  1104
# Check max IDs used across all team\outcome (1104):  1104
# Number of accounts in the subm file:  160
# We have 103 submissions for eviction
# We have 66 submissions for eviction which have an r2>0
# The min E(w) for eviction vs prev is -0.46868889651625445
# The min E(w) for eviction vs benchmark is -0.47009326415670016
# The max E(w) for eviction vs prev is 0.0074824111270946495
# The max E(w) for eviction vs benchmark is 0.004819421990921943
# Spearmans Rho for incremental r2 and ew for eviction: 0.9719289668848947
# We have 106 submissions for jobTraining
# We have 63 submissions for jobTraining which have an r2>0
# The min E(w) for jobTraining vs prev is -0.33708800354315555
# The min E(w) for jobTraining vs benchmark is -0.35518009093815717
# The max E(w) for jobTraining vs prev is 0.02805900438011931
# The max E(w) for jobTraining vs benchmark is 1.3836795196049295e-06
# Spearmans Rho for incremental r2 and ew for jobTraining: 0.9953228448082835
# We have 109 submissions for layoff
# We have 51 submissions for layoff which have an r2>0
# The min E(w) for layoff vs prev is -0.3652429783956843
# The min E(w) for layoff vs benchmark is -0.3677424507297249
# The max E(w) for layoff vs prev is 0.014461069015638152
# The max E(w) for layoff vs benchmark is 0.010466442269238138
# Spearmans Rho for incremental r2 and ew for layoff: 0.9817667617536897

# %%
import os
import rpy2.robjects as robjects
from figure_1_function import make_figure_one
from figure_a1_function import make_figure_a1
from figure_2_function import make_figure_two
from figure_3_function import make_figure_three
from figure_4_function import make_figure_four
from figure_5_function import make_figure_five
from figure_6_function import make_figure_six
from figure_7_function import make_figure_seven
from make_logreg_figure import make_logreg_plotter
from titanic_competition import titanic_main
figure_path = os.path.join(os.getcwd(), '..', 'results', 'figures')
sim_path = os.path.join(os.getcwd(), '..', 'data', 'sims')
data_path = os.path.join(os.getcwd(), '..', 'data')
table_path = os.path.join(os.getcwd(), '..', 'results', 'tables')
# %load_ext autoreload
# %autoreload 2

score_holder, prob_holder = titanic_main(data_path, table_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0.917157  0.951593     0.990956  0.971621  0.984661  0.383271
# 1   0.144653  0.157494     0.022169  0.080895  0.093757  0.383271
# 2   0.429731  0.275603     0.528792  0.479052  0.464565  0.383271
# 3   0.114061  0.157479     0.015708  0.211079  0.233816  0.383271
# 4   0.226767  0.131127     0.164011  0.153195  0.044313  0.383271
# ..       ...       ...          ...       ...       ...       ...
# 85  0.890736  0.932745     0.997101  0.985599  1.000000  0.383271
# 86  0.082158  0.157474     0.010254  0.067980  0.074560  0.383271
# 87  0.048903  0.157438     0.000961  0.016162  0.000000  0.383271
# 88  0.642732  0.444960     0.857858  0.192770  0.073979  0.383271
# 89  0.453624  0.394212     0.884697  0.068766  0.003333  0.383271
#
# [90 rows x 6 columns]
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0.307476  0.544891     0.746763  0.641480  0.727116  0.382793
# 1   0.847444  0.855184     0.954345  0.832820  0.706667  0.382793
# 2   0.639953  0.534944     0.922633  0.341713  0.329003  0.382793
# 3   0.089136  0.161745     0.010547  0.086507  0.097010  0.382793
# 4   0.707179  0.830359     0.905654  0.924324  0.927738  0.382793
# ..       ...       ...          ...       ...       ...       ...
# 84  0.506055  0.327782     0.971792  0.225076  0.290000  0.382793
# 85  0.583445  0.631977     0.922155  0.514151  0.498253  0.382793
# 86  0.775549  0.830095     0.841015  0.947821  0.990000  0.382793
# 87  0.802245  0.893493     0.952309  0.994610  0.971389  0.382793
# 88  0.237072  0.161776     0.060264  0.120053  0.124866  0.382793
#
# [89 rows x 6 columns]
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0.598525  0.674231     0.927754  0.571737  0.475282  0.386534
# 1   0.105820  0.162496     0.012373  0.143842  0.160744  0.386534
# 2   0.105820  0.162496     0.012373  0.143842  0.160744  0.386534
# 3   0.672423  0.820024     0.649362  0.722193  0.732515  0.386534
# 4   0.085083  0.162457     0.009081  0.081242  0.087594  0.386534
# ..       ...       ...          ...       ...       ...       ...
# 84  0.071290  0.111010     0.057844  0.438055  0.609820  0.386534
# 85  0.054750  0.135766     0.001284  0.015957  0.000000  0.386534
# 86  0.105820  0.162496     0.012373  0.143842  0.160744  0.386534
# 87  0.476666  0.280942     0.939946  0.052699  0.000000  0.386534
# 88  0.080236  0.162411     0.018339  0.168006  0.157442  0.386534
#
# [89 rows x 6 columns]
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0
rows x 6 columns]
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0.141310  0.155556     0.055383  0.081077  0.102052  0.376559
# 1   0.072310  0.145024     0.017350  0.112715  0.116586  0.376559
# 2   0.929470  0.954637     0.998408  0.996909  1.000000  0.376559
# 3   0.698840  0.829388     0.740505  0.746291  0.768414  0.376559
# 4   0.084084  0.117248     0.116061  0.239439  0.323357  0.376559
# ..       ...       ...          ...       ...       ...       ...
# 84  0.073286  0.144962     0.008428  0.069940  0.073493  0.376559
# 85  0.929470  0.954637     0.998408  0.996909  1.000000  0.376559
# 86  0.280752  0.144997     0.843544  0.184734  0.144615  0.376559
# 87  0.177570  0.147223     0.123665  0.185543  0.083071  0.376559
# 88  0.207949  0.144957     0.052413  0.096936  0.127657  0.376559
#
# [89 rows x 6 columns]
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0.925267  0.939307     0.998647  0.998533  1.000000  0.380299
# 1   0.047263  0.136318     0.001818  0.109390  0.165501  0.380299
# 2   0.643492  0.455458     0.683008  0.855315  0.557143  0.380299
# 3   0.119433  0.161369     0.015455  0.193314  0.194770  0.380299
# 4   0.125653  0.161368     0.213604  0.185029  0.264107  0.380299
# ..       ...       ...          ...       ...       ...       ...
# 84  0.707021  0.662127     0.959885  0.787038  0.656316  0.380299
# 85  0.900279  0.926673     0.997957  0.987578  1.000000  0.380299
# 86  0.821592  0.873830     0.988686  0.848867  0.823299  0.380299
# 87  0.591258  0.274479     0.886944  0.393709  0.280028  0.380299
# 88  0.156834  0.161280     0.030254  0.073917  0.079851  0.380299
#
# [89 rows x 6 columns]
#     Logistic       SVC  Naive Bayes  LightGBM        RF  Baseline
# 0   0.912302  0.932398     0.997491  0.981749  1.000000  0.389027
# 1   0.640806  0.466163     0.932003  0.203293  0.187638  0.389027
# 2   0.732851  0.795861     0.620340  0.888316  0.910767  0.389027
# 3   0.570567  0.559152     0.954559  0.441623  0.512780  0.389027
# 4   0.820901  0.594347     0.976568  0.296778  0.317786  0.389027
# ..       ...       ...          ...       ...       ...       ...
# 84  0.054708  0.120141     0.001408  0.019700  0.000000  0.389027
# 85  0.080064  0.154437     0.020461  0.129479  0.127252  0.389027
# 86  0.080064  0.154437     0.020461  0.129479  0.127252  0.389027
# 87  0.040659  0.141059     0.001948  0.173806  0.217559  0.389027
# 88  0.546039  0.702482     0.635136  0.394612  0.447453  0.389027
#
# [89 rows x 6 columns]
#                   Logistic    SVC  Naive Bayes  LightGBM     RF  Baseline
# Log Loss             0.449  0.449        0.625     0.434  0.508     0.667
# Accuracy             0.807  0.809        0.768     0.837  0.823     0.616
# Brier Score Loss     0.142  0.141        0.179     0.132  0.138     0.237
# F1                   0.741  0.735        0.721     0.772  0.758     0.000
# ROC-AUC              0.860  0.849        0.843     0.865  0.857     0.500
# Jaccard              0.590  0.584        0.566     0.630  0.613     0.000
# R2                   0.400  0.405        0.243     0.442  0.415     0.000
# IMV                  0.395  0.392        0.146     0.410  0.292     0.000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
pairplot = sns.pairplot(prob_holder[['Logistic', 'SVC', 'Naive Bayes', 'LightGBM', 'RF']])
pairplot.savefig(os.path.join(figure_path, 'titanic_preds.pdf'))
